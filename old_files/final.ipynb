# %% [markdown]
# <a href="https://colab.research.google.com/github/Nilanshrajput/Video_Generation_Transformer/blob/master/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import os
from collections import OrderedDict
from torch.autograd import Variable
import torch.nn as nn
from torch.nn import init
import functools
import torchvision.models as models

from __future__ import absolute_import, division, print_function, unicode_literals


from torchvision import models
import torch
import torch.nn as nn
import torchvision
from torch.autograd import Variable
from torchvision import transforms, utils
import matplotlib.pyplot as plt

from skimage import io
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils
import re

import argparse
import warnings
from datetime import datetime
from glob import glob
from shutil import copyfile


from torch import autograd
from torch.nn import functional as F
import torch.nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.distributed as dist
import torch.optim
import torch.multiprocessing as mp
import torch.utils.data
import torch.utils.data.distributed

# %%
import os
import re
import math
from pathlib import Path
# Suppose you are trying to load pre-trained resnet model in directory- models\resnet

os.environ['TORCH_HOME'] = 'D:\dev\Pytorch_Models\models\\resnet' #setting the environment variable

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 134923 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.13-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.13-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.13-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
home ="drive/dl_projects/Video_Genaeration/output"
home = Path(home)
import tensorflow
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# !ls "drive/dl_projects/Video_Genaeration/"
# Out:
# img.jpg  Model1  output  Pix2Pix.ipynb	Transformer.ipynb  Video_Gen

# %%
# !wget --header="Host: www.cityscapes-dataset.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3" --header="Accept-Language: en-GB,en-US;q=0.9,en;q=0.8" --header="Referer: https://www.cityscapes-dataset.com/downloads/" --header="Cookie: PHPSESSID=4f0gk1d5hbc0ikttngvpm8ff52" --header="Connection: keep-alive" "https://www.cityscapes-dataset.com/file-handling/?packageID=4" -O "leftImg8bit_trainextra.zip" -c
# Out:
# --2019-11-21 06:16:20--  https://www.cityscapes-dataset.com/file-handling/?packageID=4
# Resolving www.cityscapes-dataset.com (www.cityscapes-dataset.com)... 139.19.217.8
# Connecting to www.cityscapes-dataset.com (www.cityscapes-dataset.com)|139.19.217.8|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 47230218747 (44G) [application/octet-stream]
# Saving to: ‘leftImg8bit_trainextra.zip’
#
# leftImg8bit_trainex 100%[===================>]  43.99G   104MB/s    in 7m 47s
#
# 2019-11-21 06:24:07 (96.5 MB/s) - ‘leftImg8bit_trainextra.zip’ saved [47230218747/47230218747]

# %%
# !unzip leftImg8bit_trainextra.zip
# Out:
# Archive:  leftImg8bit_trainextra.zip
#  extracting: README
#  extracting: license.txt
#    creating: leftImg8bit/train_extra/
#    creating: leftImg8bit/train_extra/heilbronn/
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000465_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000029_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000084_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000165_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000429_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000403_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000380_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000292_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000605_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000689_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000588_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000006_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000324_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000711_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000466_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000425_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000334_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000381_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000183_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000601_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000138_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000279_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000402_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000634_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000495_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000360_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000704_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000046_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000147_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000551_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000223_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000491_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000139_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000217_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000643_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000456_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000083_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000151_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000302_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000200_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000184_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000201_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000068_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000577_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000502_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000176_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000105_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000143_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000284_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000541_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000528_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000408_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000658_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000687_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000250_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000079_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000186_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000703_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000060_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000399_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000430_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000724_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000001_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000185_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000021_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000227_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000579_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000368_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000376_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000225_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000339_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000584_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000563_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000352_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000219_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000312_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000358_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000553_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000453_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000648_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000283_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000044_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000717_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000127_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000313_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000086_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000221_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000318_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000055_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000591_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000663_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000422_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000116_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000306_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000441_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000014_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000205_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000644_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000631_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000215_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000208_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000723_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000446_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000094_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000229_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000087_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000361_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000245_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000270_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000340_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000018_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000636_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000122_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000335_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000363_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000140_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000226_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000621_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000023_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000299_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000442_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000683_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000047_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000649_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000045_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000377_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000220_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000558_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000513_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000619_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000092_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000725_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000002_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000712_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000343_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000698_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000447_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000431_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000336_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000342_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000602_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000239_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000666_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000567_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000191_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000395_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000586_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000180_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000728_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000708_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000393_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000614_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000547_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000242_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000075_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000322_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000082_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000639_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000460_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000497_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000685_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000097_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000054_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000133_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000439_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000369_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000142_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000706_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000019_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000386_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000583_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000218_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000492_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000414_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000315_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000013_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000448_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000508_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000043_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000287_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000256_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000615_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000629_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000364_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000561_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000152_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000575_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000618_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000233_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000341_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000282_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000374_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000251_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000196_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000056_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000109_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000531_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000202_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000357_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000661_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000320_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000481_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000234_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000533_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000077_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000203_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000266_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000198_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000627_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000726_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000421_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000694_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000673_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000556_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000552_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000512_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000488_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000307_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000316_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000572_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000051_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000246_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000101_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000653_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000311_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000308_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000005_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000440_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000532_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000224_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000163_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000052_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000112_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000166_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000121_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000412_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000454_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000003_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000519_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000464_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000067_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000542_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000062_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000700_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000503_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000490_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000027_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000413_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000131_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000398_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000309_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000199_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000510_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000231_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000590_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000667_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000124_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000235_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000656_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000290_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000544_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000344_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000499_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000535_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000562_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000388_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000305_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000113_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000378_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000613_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000426_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000509_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000680_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000684_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000281_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000272_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000100_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000435_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000650_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000635_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000523_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000104_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000065_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000261_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000134_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000709_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000265_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000415_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000330_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000483_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000710_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000611_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000716_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000160_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000210_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000529_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000405_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000137_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000038_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000671_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000356_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000157_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000557_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000522_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000701_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000164_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000008_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000350_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000372_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000328_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000367_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000624_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000632_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000348_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000193_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000392_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000154_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000373_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000222_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000569_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000721_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000697_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000041_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000550_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000473_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000487_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000383_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000093_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000207_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000444_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000566_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000520_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000323_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000276_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000560_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000240_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000026_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000546_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000484_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000015_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000686_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000053_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000020_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000457_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000153_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000071_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000167_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000011_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000347_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000030_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000638_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000333_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000389_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000485_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000211_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000559_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000074_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000159_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000040_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000144_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000301_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000300_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000608_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000655_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000070_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000548_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000472_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000516_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000486_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000384_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000241_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000189_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000581_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000713_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000699_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000461_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000564_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000130_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000125_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000543_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000610_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000228_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000476_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000445_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000150_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000692_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000355_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000727_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000391_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000720_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000521_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000314_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000037_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000477_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000693_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000268_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000273_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000707_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000321_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000455_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000072_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000156_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000192_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000025_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000366_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000573_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000197_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000132_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000048_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000609_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000688_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000702_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000617_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000630_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000286_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000424_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000458_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000585_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000009_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000410_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000582_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000620_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000022_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000331_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000420_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000554_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000641_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000555_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000158_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000146_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000123_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000036_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000248_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000675_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000494_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000478_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000511_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000332_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000236_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000375_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000212_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000506_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000135_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000194_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000409_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000076_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000090_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000423_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000401_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000719_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000467_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000039_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000690_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000098_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000718_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000371_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000110_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000178_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000419_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000188_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000396_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000117_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000565_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000450_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000616_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000362_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000527_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000095_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000089_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000504_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000111_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000278_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000576_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000652_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000359_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000274_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000603_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000387_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000289_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000108_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000264_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000155_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000526_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000063_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000397_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000394_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000594_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000654_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000126_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000705_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000254_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000438_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000443_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000496_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000642_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000474_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000691_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000317_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000035_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000645_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000715_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000598_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000066_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000291_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000468_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000145_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000064_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000599_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000385_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000500_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000024_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000187_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000475_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000237_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000128_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000260_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000118_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000434_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000081_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000479_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000259_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000427_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000587_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000574_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000449_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000288_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000524_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000277_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000451_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000626_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000033_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000106_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000004_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000244_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000545_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000073_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/heilbronn/heilbronn_000000_000662_leftImg8bit.png
# ...
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001474_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001052_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000050_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000951_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001455_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000560_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000209_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000090_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001196_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001336_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001260_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000361_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000122_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000851_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000212_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001095_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000900_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000625_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000904_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000313_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000146_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001480_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001025_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001411_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000778_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001424_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000229_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000568_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000448_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000261_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000443_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000154_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000993_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000744_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000322_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001106_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000495_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000594_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000899_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001291_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000552_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001013_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001184_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001101_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001000_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000557_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000267_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001059_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000386_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000573_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001093_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001476_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000582_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000077_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000797_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000962_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001344_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000527_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000775_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001008_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000298_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000006_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000722_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001341_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000150_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001160_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001208_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001254_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000487_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001444_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000829_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000500_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001111_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000258_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001466_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001382_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001212_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000991_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000119_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001320_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000356_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000683_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000018_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000565_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001043_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000976_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001457_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000224_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000599_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000390_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000272_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001385_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000769_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000208_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000577_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000574_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000310_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001294_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000235_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000403_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000663_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000999_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000351_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000875_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001414_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000230_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000728_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000837_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000350_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000861_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000808_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000260_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001056_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000192_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000334_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000927_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000680_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000129_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000188_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001453_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000056_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000095_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001044_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000493_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000028_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001447_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001206_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000725_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000287_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001465_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001188_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000767_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000173_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000504_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000182_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000649_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001334_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000051_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001084_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000798_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000113_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001019_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000204_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000106_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000954_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000458_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001017_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000755_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000476_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001373_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000439_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001194_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000651_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001270_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001027_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000435_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000354_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000379_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001269_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000167_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001028_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000589_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000344_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001109_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000164_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000668_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000548_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000985_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000883_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001421_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001446_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000073_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000965_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000666_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001126_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_001302_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000376_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000639_leftImg8bit.png
#  extracting: leftImg8bit/train_extra/nuremberg/nuremberg_000000_000431_leftImg8bit.png

# %%
import json
import os
from collections import namedtuple
import zipfile

from PIL import Image


class CityscapeDataset(Dataset):
    """`Cityscapes <http://www.cityscapes-dataset.com/>`_ Dataset.

    Args:
        root (string): Root directory of dataset where directory ``leftImg8bit``
            
        split (string, optional): The image split to use, ``train``, ``train_extra`` or ``val``
       
        transform (callable, optional): A function/transform that takes in a PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``  
        transforms (callable, optional): A function/transform that takes input sample and its target as entry
            and returns a transformed version.

    Examples:

      
    """

    # Based on https://github.com/mcordts/cityscapesScripts
  

    def __init__(self, root=None, split='train_extra', transforms=None):
        if root is not None:
          self.images_dir = os.path.join(self.root, 'leftImg8bit', split)
        else:
          self.images_dir = os.path.join('leftImg8bit', split)
        self.split = split
        self.images = []
        self.root = root
        self.transforms = transforms
  
        #valid_modes = ("train", "train_extra", "val")
        
        for city in os.listdir(self.images_dir):
            img_dir = os.path.join(self.images_dir, city)
            images_city=[]
            for file_name in os.listdir(img_dir):
                
                images_city.append(os.path.join(img_dir, file_name))
            # re.split(\d+,input) splits by integer value
            images_city.sort( key= lambda text: int(re.split('(\d+)',text)[3]+re.split('(\d+)',text) [5] ))
            self.images+=images_city
        
    def paths_dir(self):
      return(self.images)

    def im_path(self):
      return self.images            
    def __getitem__(self, index):
        """
        Args:
            index (int): Index
        Returns:
             image 
        """

        image = Image.open(self.images[index]).convert('RGB')
        if self.transforms is not None:
            image = self.transforms(image)

        return image


    def __len__(self):
        return len(self.images)

# %%
import json
import os
from collections import namedtuple
import zipfile

from PIL import Image


class CityscapeDataset(Dataset):
    """`Cityscapes <http://www.cityscapes-dataset.com/>`_ Dataset.

    Args:
        root (string): Root directory of dataset where directory ``leftImg8bit``
            
        split (string, optional): The image split to use, ``train``, ``train_extra`` or ``val``
       
        transform (callable, optional): A function/transform that takes in a PIL image
            and returns a transformed version. E.g, ``transforms.RandomCrop``  
        transforms (callable, optional): A function/transform that takes input sample and its target as entry
            and returns a transformed version.

    Examples:

      
    """

    # Based on https://github.com/mcordts/cityscapesScripts
  

    def __init__(self, root=None, split='train_extra', transforms=None):
        if root is not None:
          self.images_dir = os.path.join(self.root, 'leftImg8bit', split)
        else:
          self.images_dir = os.path.join('leftImg8bit', split)
        self.split = split
        self.images = []
        self.root = root
        self.transforms = transforms
  
        #valid_modes = ("train", "train_extra", "val")
        
        for city in os.listdir(self.images_dir):
            img_dir = os.path.join(self.images_dir, city)
            images_city=[]
            for file_name in os.listdir(img_dir):
                
                images_city.append(os.path.join(img_dir, file_name))
            # re.split(\d+,input) splits by integer value
            images_city.sort( key= lambda text: int(re.split('(\d+)',text)[3]+re.split('(\d+)',text) [5] ))
            self.images+=images_city
        
    def print_dir(self):
      print(self.images)

    def im_path(self):
      return self.images            
    def __getitem__(self, index):
        """
        Args:
            index (int): Index
        Returns:
             image 
        """

        image = Image.open(self.images[index]).convert('RGB')
        if self.transforms is not None:
            image = self.transforms(image)

        return image


    def __len__(self):
        return len(self.images)

# %%
scaler = transforms.Resize((256, 256))
to_tensor = transforms.ToTensor()

# %%
#not adding normalization as image looses textures and clrs for recostruction

composed_transforms=transforms.Compose([scaler,to_tensor])

# %%
transformed_dataset = CityscapeDataset(
                                           transforms=composed_transforms
                                           )

# %%
#x=next(iter(dataloader))

# %%
class ResNet50Bottom(nn.Module):
    def __init__(self, original_model):
        super(ResNet50Bottom, self).__init__()
        self.features = nn.Sequential(*list(original_model.children())[:-5])
        
    def forward(self, x):
        x = self.features(x)
        return x

# %%
#res50_model = models.resnet50(pretrained=True)
#res50_conv2 = ResNet50Bottom(res50_model).cuda()
#
#outputs = res50_conv2(x.to('cuda'))
#outputs.data.shape

# %%
class FeatureChanger(nn.Module):
    def __init__(self,in_channels, out_channels):
        super().__init__()
        
        self.kernel_size = 1

        self.in_channels = in_channels
        self.out_channels = out_channels
        self.conv2d_0 = torch.nn.Conv2d(in_channels, out_channels, self.kernel_size, stride=1)
        #self.con2d_1 = torch.nn.Conv2d(out_channels*2, out_channels, kernel_size, stride=1)
        
    def forward(self, batch):
        x = self.conv2d_0(batch)
        #x = self.con2d_1(x)
        return x

# %%
class MaskedSelfAttention(nn.Module):

  def __init__(self,heads, d_model, dropout= .4):
    super().__init__()

    self.d_model = d_model
    self.heads = heads
    self.soft2d = nn.Softmax2d()
    self.drop = nn.Dropout(dropout)
    

  def _generate_square_subsequent_mask(self, sz):
    #sz= batch size
    mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask

  def mult_4d(self, batch, q_w):
    bs= batch.shape[0]
    layers = batch.shape[1]
    dim1 = batch.shape[2]
    dim2 = batch.shape[3]
    output = torch.bmm(batch.view(bs*layers,dim1,dim2), q_w.view(bs*layers,dim1,dim2))
    return output.view(bs,layers,dim1,dim2)




  def forward(self, q , k, v):

    #score
    attn_output_weights = self.mult_4d(q, k.transpose(-2,-1))/math.sqrt(self.d_model/2)
    soft_scores = self.soft2d(attn_output_weights)
    soft_scores = self.drop(soft_scores).to('cuda')
    output = self.mult_4d(v, soft_scores)

    return output

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, bs, heads, d_model, dim1, dim2, dropout = 0.4):
        super().__init__()
        
        self.d_model = d_model
        self.h = heads
        self.dim1 = dim1
        self.dim2 =dim2
        self.dropout = dropout
        self.nu_feat =d_model # int(d_model/self.h*2)
        self.bs = bs
        res50_model = models.resnet50(pretrained=True)
        self.resnet_back = ResNet50Bottom(res50_model).cuda()


        self.q_3d = torch.nn.Parameter(torch.empty(bs,self.nu_feat,dim1,dim2,requires_grad=True))
        self.k_3d = torch.nn.Parameter(torch.empty(bs,self.nu_feat,dim1,dim2,requires_grad=True))
        self.v_3d = torch.nn.Parameter(torch.empty(bs,self.nu_feat,dim1,dim2,requires_grad=True))
   

        nn.init.kaiming_normal_(self.q_3d, mode='fan_in')
        nn.init.kaiming_normal_(self.k_3d, mode='fan_in')
        nn.init.kaiming_normal_(self.v_3d, mode='fan_in')

        self.attention_layer= MaskedSelfAttention(self.h,d_model,dropout)
    
    def mult_4d(self, batch, q_w, bs):
      
      layers = batch.shape[1]
      dim1 = batch.shape[2]
      dim2 = batch.shape[3]
      #print(layers, dim1,dim2,bs)
      #print(q_w.shape)
      output = torch.bmm(batch.view(bs*layers,dim1,dim2), q_w.view(bs*layers,dim1,dim2))
      return output.view(bs,layers,dim1,dim2)

    def forward(self, batch, mask=None):
        bs = batch.size(0)
        batch = batch.to('cuda')
        """ 
        batch = self.resnet_back(batch.to('cuda'))        
        channels = batch.shape[1]
        feature_layer1 = FeatureChanger(channels,int(channels/self.h*2)).cuda()
        batch = feature_layer1(batch)

        """

        q = self.mult_4d(batch,self.q_3d.to('cuda'),bs)
        k = self.mult_4d(batch,self.k_3d.to('cuda'),bs)
        v = self.mult_4d(batch,self.v_3d.to('cuda'),bs)

        """
        #divide feature space in no of heads each head works on certain features only
        #returns tuple of size=heads

        batch_chunks= torch.chunk(batch, heads, dim=1)
        #converting tuple to tensor
        batch_chunks = torch.stack(batch_chunks, dim =0)
        """

        attention_out = self.attention_layer( q, k, v)
        #feature_layer2 = FeatureChanger(int(channels/self.h*2),channels).cuda()
        #output = feature_layer2(batch)
        output = attention_out
  
    
        return output

# %%
batch_size = 2
dataloader = DataLoader(transformed_dataset, batch_size,
                        sampler=torch.utils.data.SequentialSampler(transformed_dataset) , num_workers=4)

# %%
"""
heads = 8
d_model = 3
dim1 = dim2= 224
dropout = 0.4


MHA= MultiHeadAttention(batch_size, heads, d_model, dim1, dim2, dropout = 0.4)

"""
# Out:
# '\nheads = 8\nd_model = 3\ndim1 = dim2= 224\ndropout = 0.4\n\n\nMHA= MultiHeadAttention(batch_size, heads, d_model, dim1, dim2, dropout = 0.4)\n\n'

# %%
#output = MHA(next(iter(dataloader)))

# %%
#output.shape

# %%
# taken from singan implementaion from repo given below
# https://github.com/FriedRonaldo/SinGAN
#
class Generator(nn.Module):
    def __init__(self, img_size_min, num_scale, size_list, bs, heads, d_model, dim1, dim2, dropout = 0.4, scale_factor=4/3):
        super(Generator, self).__init__()
        self.img_size_min = img_size_min
        self.scale_factor = scale_factor
        self.num_scale = num_scale
        self.nf = 32
        self.current_scale = 0
        self.d_model = d_model
        self.h = heads
        self.dim1 = dim1
        self.dim2 =dim2
        self.dropout = dropout
        self.nu_feat =d_model # int(d_model/self.h*2)
        self.bs = bs

        self.size_list = size_list #[int(self.img_size_min * scale_factor**i) for i in range(num_scale + 1)]
        print(self.size_list)
        self.MHA= MultiHeadAttention(bs, heads, d_model, dim1, dim2, dropout )
        self.sub_generators = nn.ModuleList()

        first_generator = nn.ModuleList()

        first_generator.append(nn.Sequential(nn.Conv2d(3, self.nf, 3, 1),
                                             nn.BatchNorm2d(self.nf),
                                             nn.LeakyReLU(2e-1)))
        for _ in range(3):
            first_generator.append(nn.Sequential(nn.Conv2d(self.nf, self.nf, 3, 1),
                                                 nn.BatchNorm2d(self.nf),
                                                 nn.LeakyReLU(2e-1)))

        first_generator.append(nn.Sequential(nn.Conv2d(self.nf, 3, 3, 1),
                                             nn.Tanh()))

        first_generator = nn.Sequential(*first_generator)

        self.sub_generators.append(first_generator)

    def forward(self, batch, img=None):
        x_list = []
        #print(batch[0].shape)
        dim2 = dim1 = batch[0].shape[-1]
        #self.MHA= MultiHeadAttention(self.bs, self.h, self.d_model,  dim1,  dim2, self.dropout )
        #x_first = self.sub_generators[0](self.MHA(batch[0]))
        #print(x_first.size())
        x_first = self.sub_generators[0](batch[0])
        x_list.append(x_first)

        if img is not None:
            x_inter = img
        else:
            x_inter = x_first

        for i in range(1, self.current_scale + 1):
            x_inter = F.interpolate(x_inter, (self.size_list[i], self.size_list[i]), mode='bilinear', align_corners=True)
            #print(x_inter.size())
            x_prev = x_inter
            x_inter = F.pad(x_inter, [5, 5, 5, 5], value=0)
            #print(self.current_scale)
            dim2 = dim1 = batch[i].shape[-1]
            """
            self.MHA= MultiHeadAttention(self.bs, self.h, self.d_model,  dim1,  dim2, self.dropout )
            x_inter = x_inter + self.MHA(batch[i])
            """
            x_inter = x_inter + (batch[i])
            x_inter = self.sub_generators[i](x_inter) + x_prev
            x_list.append(x_inter)
        #print(self.size_list)
        return x_list

    def progress(self):
        self.current_scale += 1

        if self.current_scale % 4 == 0:
            self.nf *= 2

        tmp_generator = nn.ModuleList()
        tmp_generator.append(nn.Sequential(nn.Conv2d(3, self.nf, 3, 1),
                                           nn.BatchNorm2d(self.nf),
                                           nn.LeakyReLU(2e-1)))

        for _ in range(3):
            tmp_generator.append(nn.Sequential(nn.Conv2d(self.nf, self.nf, 3, 1),
                                               nn.BatchNorm2d(self.nf),
                                               nn.LeakyReLU(2e-1)))

        tmp_generator.append(nn.Sequential(nn.Conv2d(self.nf, 3, 3, 1),
                                           nn.Tanh()))

        tmp_generator = nn.Sequential(*tmp_generator)

        if self.current_scale % 4 != 0:
            prev_generator = self.sub_generators[-1]

            # Initialize layers via copy
            if self.current_scale >= 1:
                tmp_generator.load_state_dict(prev_generator.state_dict())

        self.sub_generators.append(tmp_generator)
        print("GENERATOR PROGRESSION DONE")

# %%
# taken from singan implementaion from repo given below
# https://github.com/FriedRonaldo/SinGAN
#


class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.nf = 32
        self.current_scale = 0

        self.sub_discriminators = nn.ModuleList()

        first_discriminator = nn.ModuleList()

        first_discriminator.append(nn.Sequential(nn.Conv2d(3, self.nf, 3, 1, 1),
                                             nn.LeakyReLU(2e-1)))
        for _ in range(3):
            first_discriminator.append(nn.Sequential(nn.Conv2d(self.nf, self.nf, 3, 1, 1),
                                                 nn.BatchNorm2d(self.nf),
                                                 nn.LeakyReLU(2e-1)))

        first_discriminator.append(nn.Sequential(nn.Conv2d(self.nf, 1, 3, 1, 1)))

        first_discriminator = nn.Sequential(*first_discriminator)

        self.sub_discriminators.append(first_discriminator)

    def forward(self, x):
        out = self.sub_discriminators[self.current_scale](x)
        return out

    def progress(self):
        self.current_scale += 1
        # Lower scale discriminators are not used in later ... replace append to assign?
        if self.current_scale % 4 == 0:
            self.nf *= 2

        tmp_discriminator = nn.ModuleList()
        tmp_discriminator.append(nn.Sequential(nn.Conv2d(3, self.nf, 3, 1, 1),
                                               nn.LeakyReLU(2e-1)))

        for _ in range(3):
            tmp_discriminator.append(nn.Sequential(nn.Conv2d(self.nf, self.nf, 3, 1, 1),
                                                   nn.BatchNorm2d(self.nf),
                                                   nn.LeakyReLU(2e-1)))

        tmp_discriminator.append(nn.Sequential(nn.Conv2d(self.nf, 1, 3, 1, 1)))

        tmp_discriminator = nn.Sequential(*tmp_discriminator)

        if self.current_scale % 4 != 0:
            prev_discriminator = self.sub_discriminators[-1]

            # Initialize layers via copy
            if self.current_scale >= 1:
                tmp_discriminator.load_state_dict(prev_discriminator.state_dict())

        self.sub_discriminators.append(tmp_discriminator)
        print("DISCRIMINATOR PROGRESSION DONE")

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def compute_grad_gp(d_out, x_in):
    batch_size = x_in.size(0)
    grad_dout = autograd.grad(
        outputs=d_out.sum(), inputs=x_in,grad_outputs=torch.ones_like(d_out.sum()),
        create_graph=True, retain_graph=True, only_inputs=True)[0]
    grad_dout2 = grad_dout.pow(2)
    assert(grad_dout2.size() == x_in.size())
    reg = grad_dout2.view(batch_size, -1).sum(1)
    return reg


def compute_grad_gp_wgan(D, x_real, x_fake, gpu):
    alpha = torch.rand(x_real.size(0), 1, 1, 1).cuda(gpu)

    x_interpolate = ((1 - alpha) * x_real + alpha * x_fake).detach()
    x_interpolate.requires_grad = True
    d_inter_logit = D(x_interpolate)
    grad = torch.autograd.grad(d_inter_logit, x_interpolate,
                               grad_outputs=torch.ones_like(d_inter_logit), create_graph=True)[0]

    norm = grad.view(grad.size(0), -1).norm(p=2, dim=1)

    d_gp = ((norm - 1) ** 2).mean()
    return d_gp

# %%
# taken from singan implementaion from repo given below
# https://github.com/FriedRonaldo/SinGAN
#

from tqdm import trange
import torchvision.utils as vutils


def trainSinGAN(data_loader, networks, opts, stage, args, additional):
  # avg meter
  d_losses = AverageMeter()
  g_losses = AverageMeter()

  # set nets
  D = networks[0]
  G = networks[1]
  # set opts
  d_opt = opts['d_opt']
  g_opt = opts['g_opt']
  # switch to train mode
  D.train()
  G.train()
  # summary writer
  # writer = additional[0]
  train_it = iter(data_loader)
  # total_iter = 2000 * (args.num_scale - stage + 1)
  # decay_lr = 1600 * (args.num_scale - stage + 1)
  total_iter = 2000
  decay_lr = 4

  d_iter = 3
  g_iter = 3

  t_train = trange(0, total_iter, initial=0, total=total_iter)
  x_in = next(train_it)

  x_in = x_in.cuda( non_blocking=True)
  x_org = x_in
  x_in = F.interpolate(x_in, (args.size_list[stage], args.size_list[stage]), mode='bilinear', align_corners=True)
  #x_0 = F.interpolate(x_0, (args.size_list[stage], args.size_list[stage]), mode='bilinear', align_corners=True)
  
  

  """
  z_rec = additional['z_rec']

  for z_idx in range(len(z_rec)):
      z_rec[z_idx] = z_rec[z_idx].cuda(args.gpu, non_blocking=True)

  x_in = next(train_it)

  x_in = x_in.cuda(args.gpu, non_blocking=True)
  x_org = x_in
  x_in = F.interpolate(x_in, (args.size_list[stage], args.size_list[stage]), mode='bilinear', align_corners=True)
  vutils.save_image(x_in.detach().cpu(), os.path.join(args.res_dir, 'ORGTRAIN_{}.png'.format(stage)),
                    nrow=1, normalize=True)
   """
  x_in_list = []

  for xidx in range(0, stage + 1):
      x_tmp = F.interpolate(x_org, (args.size_list[xidx], args.size_list[xidx]), mode='bilinear', align_corners=True)
      x_tmp = F.pad(x_tmp, [5, 5, 5, 5], value=0)
      x_in_list.append(x_tmp)
  
  x_in_list_nopad = []
  
  for xidx in range(0, stage + 1):
      x_tmp = F.interpolate(x_org, (args.size_list[xidx], args.size_list[xidx]), mode='bilinear', align_corners=True)
      
      x_in_list_nopad.append(x_tmp)
  z_rec = F.pad(x_in, [5, 5, 5, 5], value=0)
  for i in t_train:
      if i == decay_lr:
          for param_group in d_opt.param_groups:
                  param_group['lr'] *= 0.1
                  print("DISCRIMINATOR LEARNING RATE UPDATE TO :", param_group['lr'])
          for param_group in g_opt.param_groups:
                  param_group['lr'] *= 0.1
                  print("GENERATOR LEARNING RATE UPDATE TO :", param_group['lr'])

      for _ in range(g_iter):
          g_opt.zero_grad()
          #print(type(z_rec))
          x_rec_list = G(x_in_list)
          #print(x_rec_list[-1].shape)
          #print(x_in.shape)
          g_rec = F.mse_loss(x_rec_list[-1], x_in)
          # calculate rmse for each scale
          rmse_list = [1.0]
          for rmseidx in range(1, stage + 1):
              rmse = torch.sqrt(F.mse_loss(x_rec_list[rmseidx], x_in_list_nopad[rmseidx]))
              rmse_list.append(rmse)

          z_list = [F.pad(rmse_list[z_idx] * torch.randn(args.batch_size, 3, args.size_list[z_idx],
                                              args.size_list[z_idx]).cuda(args.gpu, non_blocking=True),
                          [5, 5, 5, 5], value=0) for z_idx in range(stage + 1)]
          
          x_fake_list = G(z_list )
          #print(len(x_fake_list[-1]))

          g_fake_logit = D(x_fake_list[-1])

          ones = torch.ones_like(g_fake_logit).cuda(args.gpu)

          if args.gantype == 'wgangp':
              # wgan gp
              g_fake = -torch.mean(g_fake_logit, (2, 3))
              g_loss = g_fake + 10.0 * g_rec
          elif args.gantype == 'zerogp':
              # zero centered GP
              g_fake = F.binary_cross_entropy_with_logits(g_fake_logit, ones, reduction='none').mean()
              g_loss = g_fake + 100.0 * g_rec

          elif args.gantype == 'lsgan':
              # lsgan
              g_fake = F.mse_loss(torch.mean(g_fake_logit, (2, 3)), 0.9 * ones)
              g_loss = g_fake + 50.0 * g_rec

          g_loss.backward(retain_graph = True)
          g_opt.step()

          g_losses.update(g_loss.item(), x_in.size(0))

      # Update discriminator
      for _ in range(d_iter):
          x_in.requires_grad = True

          d_opt.zero_grad()
          x_fake_list =  G(z_list )
          

          d_fake_logit = g_fake_logit
          d_real_logit = D(x_in)

          ones = torch.ones_like(d_real_logit).cuda(args.gpu)
          zeros = torch.zeros_like(d_fake_logit).cuda(args.gpu)

          if args.gantype == 'wgangp':
              # wgan gp
              d_fake = torch.mean(d_fake_logit, (2, 3))
              d_real = -torch.mean(d_real_logit, (2, 3))
              d_gp = compute_grad_gp_wgan(D, x_in, x_fake_list[-1], args.gpu)
              d_loss = d_real + d_fake + 0.1 * d_gp
          elif args.gantype == 'zerogp':
              # zero centered GP
              # d_fake = F.binary_cross_entropy_with_logits(torch.mean(d_fake_logit, (2, 3)), zeros)
              d_fake = F.binary_cross_entropy_with_logits(d_fake_logit, zeros, reduction='none').mean()
              # d_real = F.binary_cross_entropy_with_logits(torch.mean(d_real_logit, (2, 3)), ones)
              d_real = F.binary_cross_entropy_with_logits(d_real_logit, ones, reduction='none').mean()
              #d_gp = compute_grad_gp(torch.mean(d_real_logit, (2, 3)), x_in)
              d_loss = d_real + d_fake# + 10.0 * d_gp

          elif args.gantype == 'lsgan':
              # lsgan
              d_fake = F.mse_loss(torch.mean(d_fake_logit, (2, 3)), zeros)
              d_real = F.mse_loss(torch.mean(d_real_logit, (2, 3)), 0.9 * ones)
              d_loss = d_real + d_fake

          d_loss.backward(retain_graph=True)
          d_opt.step()

          d_losses.update(d_loss.item(), x_in.size(0))

      t_train.set_description('Stage: [{}/{}] Avg Loss: D[{d_losses.avg:.3f}] G[{g_losses.avg:.3f}] RMSE[{rmse:.3f}]'
                              .format(stage, args.num_scale, d_losses=d_losses, g_losses=g_losses, rmse=rmse_list[-1]))

# %%
with open('/gdrive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive!')
# !cat '/gdrive/My Drive/foo.txt'

# %%
class Arguments():
  def __init__(self,gpu = None,gantype = 'zerogp',model_name = 'SinGan', batch_size = 128, img_size_max= 224, img_size_min=20,
               load_model = None, multiprocessing_distributed= None, world_size=1, log_dir= None, res_dir = None, num_scale = None):
    self.gpu = gpu
    self.gantype = gantype
    self.model_name = "SinGan"
    self.batch_size = batch_size
    self.img_size_max= img_size_max
    self.img_size_min=img_size_min
    self.load_model = load_model
    self.multiprocessing_distributed= multiprocessing_distributed 
    self.world_size=world_size
    self.log_dir= log_dir
    self.res_dir = res_dir 
    self.num_scale = num_scale 
    self.stage = None
    self.distributed = None
    self.workers = 8
    self.d_model = None
    self.h = None
    self.dim1 = None
    self.dim2 = None
    self.dropout = None
    self.nu_feat =None
    self.dataset = None

# %%
def save_checkpoint(state, check_list, log_dir, epoch=0):
    check_file = os.path.join(log_dir, 'model_{}.ckpt'.format(epoch))
    torch.save(state, check_file)
    check_list.write('model_{}.ckpt\n'.format(epoch))

def makedirs(path):
    if not os.path.exists(path):
        os.makedirs(path)
def formatted_print(notice, value):
    print('{0:<40}{1:<40}'.format(notice, value))

# %%
def main_worker(gpu, ngpus_per_node, args):
    args.gpu = 0


    if args.gpu is not None:
        print("Use GPU: {} for training".format(args.gpu))
    args.distributed = False
    if args.distributed:
        if args.multiprocessing_distributed:
            args.rank = args.rank * ngpus_per_node + gpu
        dist.init_process_group(backend='nccl', init_method='tcp://127.0.0.1:'+args.port,
                                world_size=args.world_size, rank=args.rank)

    ################
    # Define model #
    ################
    # 4/3 : scale factor in the paper
    scale_factor = 4/3



    tmp_scale = args.img_size_max / args.img_size_min
    args.num_scale = int(np.round(np.log(tmp_scale) / np.log(scale_factor)))
    args.size_list = [int(args.img_size_min * scale_factor**i) for i in range(args.num_scale + 1)]
    #args.size_list = [int(args.img_size_min *i) for i in range(1,args.num_scale + 1)]

    discriminator = Discriminator()
    generator = Generator(args.img_size_min, args.num_scale, args.size_list, args.batch_size, args.heads, args.d_model, args.dim1, args.dim2, args.dropout,  scale_factor)

    networks = [discriminator, generator]

    if args.distributed:
        if args.gpu is not None:
            print('Distributed to', args.gpu)
            torch.cuda.set_device(args.gpu)
            networks = [x.cuda(args.gpu) for x in networks]
            args.batch_size = int(args.batch_size / ngpus_per_node)
            args.workers = int(args.workers / ngpus_per_node)
            networks = [torch.nn.parallel.DistributedDataParallel(x, device_ids=[args.gpu], output_device=args.gpu) for x in networks]
        else:
            networks = [x.cuda() for x in networks]
            networks = [torch.nn.parallel.DistributedDataParallel(x) for x in networks]

    elif args.gpu is not None:
        torch.cuda.set_device(args.gpu)
        networks = [x.cuda(args.gpu) for x in networks]
    else:
        networks = [torch.nn.DataParallel(x).cuda() for x in networks]

    discriminator, generator, = networks

    ######################
    # Loss and Optimizer #
    ######################
    if args.distributed:
        d_opt = torch.optim.Adam(discriminator.module.sub_discriminators[0].parameters(), 5e-4, (0.5, 0.999))
        g_opt = torch.optim.Adam(generator.module.sub_generators[0].parameters(), 5e-4, (0.5, 0.999))
    else:
        d_opt = torch.optim.Adam(discriminator.sub_discriminators[0].parameters(), 5e-4, (0.5, 0.999))
        g_opt = torch.optim.Adam(generator.sub_generators[0].parameters(), 5e-4, (0.5, 0.999))

    ##############
    # Load model #
    ##############
    args.stage = 0
    if args.load_model is not None:
        check_load = open(os.path.join(args.log_dir, "checkpoint.txt"), 'r')
        to_restore = check_load.readlines()[-1].strip()
        load_file = os.path.join(args.log_dir, to_restore)
        if os.path.isfile(load_file):
            print("=> loading checkpoint '{}'".format(load_file))
            checkpoint = torch.load(load_file, map_location='cpu')
            for _ in range(int(checkpoint['stage'])):
                generator.progress()
                discriminator.progress()
            networks = [discriminator, generator]
            if args.distributed:
                if args.gpu is not None:
                    print('Distributed to', args.gpu)
                    torch.cuda.set_device(args.gpu)
                    networks = [x.cuda(args.gpu) for x in networks]
                    args.batch_size = int(args.batch_size / ngpus_per_node)
                    args.workers = int(args.workers / ngpus_per_node)
                    networks = [
                        torch.nn.parallel.DistributedDataParallel(x, device_ids=[args.gpu], output_device=args.gpu) for
                        x in networks]
                else:
                    networks = [x.cuda() for x in networks]
                    networks = [torch.nn.parallel.DistributedDataParallel(x) for x in networks]

            elif args.gpu is not None:
                torch.cuda.set_device(args.gpu)
                networks = [x.cuda(args.gpu) for x in networks]
            else:
                networks = [torch.nn.DataParallel(x).cuda() for x in networks]

            discriminator, generator, = networks

            args.stage = checkpoint['stage']
            args.img_to_use = checkpoint['img_to_use']
            discriminator.load_state_dict(checkpoint['D_state_dict'])
            generator.load_state_dict(checkpoint['G_state_dict'])
            d_opt.load_state_dict(checkpoint['d_optimizer'])
            g_opt.load_state_dict(checkpoint['g_optimizer'])
            print("=> loaded checkpoint '{}' (stage {})"
                  .format(load_file, checkpoint['stage']))
        else:
            print("=> no checkpoint found at '{}'".format(args.log_dir))

    cudnn.benchmark = True

    ###########
    # Dataset #
    ###########
    transformed_dataset = CityscapeDataset(
                                           transforms=composed_transforms
                                           )

    if args.distributed:
        train_sampler = torch.utils.data.distributed.DistributedSampler(train_dataset)
    else:
        train_sampler = None

    train_loader = DataLoader(transformed_dataset, batch_size = args.batch_size,
                            sampler=torch.utils.data.SequentialSampler(transformed_dataset) ,  num_workers=args.workers)
  

    ######################
    # Validate and Train #
    ######################
    z_fix_list = [F.pad(torch.randn(args.batch_size, 3, args.size_list[0], args.size_list[0]), [5, 5, 5, 5], value=0)]
    zero_list = [F.pad(torch.zeros(args.batch_size, 3, args.size_list[zeros_idx], args.size_list[zeros_idx]),
                       [5, 5, 5, 5], value=0) for zeros_idx in range(1, args.num_scale + 1)]
    z_fix_list = z_fix_list + zero_list
    """
    if args.validation:
        validateSinGAN(train_loader, networks, args.stage, args, {"z_rec": z_fix_list})
        return

    elif args.test:
        validateSinGAN(train_loader, networks, args.stage, args, {"z_rec": z_fix_list})
        return
    """

    if not args.multiprocessing_distributed or (args.multiprocessing_distributed and args.rank % ngpus_per_node == 0):
        check_list = open(os.path.join(args.log_dir, "checkpoint.txt"), "a+")
        record_txt = open(os.path.join(args.log_dir, "record.txt"), "a+")
        record_txt.write('DATASET\t:\t{}\n'.format(args.dataset))
        record_txt.write('GANTYPE\t:\t{}\n'.format(args.gantype))
#        record_txt.write('IMGTOUSE\t:\t{}\n'.format(args.img_to_use))
        record_txt.close()

    for stage in range(args.stage, args.num_scale + 1):
        if args.distributed:
            train_sampler.set_epoch(stage)

        trainSinGAN(train_loader, networks, {"d_opt": d_opt, "g_opt": g_opt}, stage, args, {"z_rec": z_fix_list})
       # validateSinGAN(train_loader, networks, stage, args, {"z_rec": z_fix_list})

        if args.distributed:
            discriminator.module.progress()
            generator.module.progress()
        else:
            discriminator.progress()
            generator.progress()

        networks = [discriminator, generator]

        if args.distributed:
            if args.gpu is not None:
                print('Distributed', args.gpu)
                torch.cuda.set_device(args.gpu)
                networks = [x.cuda(args.gpu) for x in networks]
                args.batch_size = int(args.batch_size / ngpus_per_node)
                args.workers = int(args.workers / ngpus_per_node)
                networks = [torch.nn.parallel.DistributedDataParallel(x, device_ids=[args.gpu], output_device=args.gpu)
                            for x in networks]
            else:
                networks = [x.cuda() for x in networks]
                networks = [torch.nn.parallel.DistributedDataParallel(x) for x in networks]

        elif args.gpu is not None:
            torch.cuda.set_device(args.gpu)
            networks = [x.cuda(args.gpu) for x in networks]
        else:
            networks = [torch.nn.DataParallel(x).cuda() for x in networks]

        discriminator, generator, = networks

        # Update the networks at finest scale
        if args.distributed:
            for net_idx in range(generator.module.current_scale):
                for param in generator.module.sub_generators[net_idx].parameters():
                    param.requires_grad = False
                for param in discriminator.module.sub_discriminators[net_idx].parameters():
                    param.requires_grad = False

            d_opt = torch.optim.Adam(discriminator.module.sub_discriminators[discriminator.current_scale].parameters(),
                                     5e-4, (0.5, 0.999))
            g_opt = torch.optim.Adam(generator.module.sub_generators[generator.current_scale].parameters(),
                                     5e-4, (0.5, 0.999))
        else:
            for net_idx in range(generator.current_scale):
                for param in generator.sub_generators[net_idx].parameters():
                    param.requires_grad = False
                for param in discriminator.sub_discriminators[net_idx].parameters():
                    param.requires_grad = False

            d_opt = torch.optim.Adam(discriminator.sub_discriminators[discriminator.current_scale].parameters(),
                                     5e-4, (0.5, 0.999))
            g_opt = torch.optim.Adam(generator.sub_generators[generator.current_scale].parameters(),
                                     5e-4, (0.5, 0.999))

        ##############
        # Save model #
        ##############
        if not args.multiprocessing_distributed or (args.multiprocessing_distributed and args.rank % ngpus_per_node == 0):
            if stage == 0:
                check_list = open(os.path.join(args.log_dir, "checkpoint.txt"), "a+")
            save_checkpoint({
                'stage': stage + 1,
                'D_state_dict': discriminator.state_dict(),
                'G_state_dict': generator.state_dict(),
                'd_optimizer': d_opt.state_dict(),
                'g_optimizer': g_opt.state_dict()
                
            }, check_list, args.log_dir, stage + 1)
            if stage == args.num_scale:
                check_list.close()

    return generator

# %%
args = Arguments()
args.gpu=0
args.distributed = False
args.load_model = None
args.batch_size = 2
args.img_size_max =  224
args.img_size_min = 28
args.heads = 8
args.d_model = 3
args.nu_feat =3
args.dim1 = 224
args.dim2 = 224
args.dropout = 0.4 
args.dataset = "train"

if args.gpu is not None:
   
    warnings.warn('You have chosen a specific GPU. This will completely '
                  'disable data parallelism.')
"""
args.distributed = args.world_size > 1 or args.multiprocessing_distributed


"""
ngpus_per_node = torch.cuda.device_count()
args.load_model = None
if args.load_model is None:
    args.model_name = '{}_{}'.format(args.model_name, datetime.now().strftime("%Y-%m-%d_%H-%M-%S"))
else:
    args.model_name = args.load_model

makedirs(home/'logs')
makedirs(home/'results')

args.log_dir = os.path.join(home,'./logs', args.model_name)
args.res_dir = os.path.join(home,'./results', args.model_name)

makedirs(args.log_dir)
makedirs(os.path.join(args.log_dir, 'codes'))
makedirs(os.path.join(args.log_dir, 'codes', 'models'))
makedirs(args.res_dir)

if args.load_model is None:
    pyfiles = glob("./*.py")
    modelfiles = glob('./models/*.py')
    for py in pyfiles:
        copyfile(py, os.path.join(args.log_dir, 'codes') + "/" + py)
    for py in modelfiles:
        copyfile(py, os.path.join(args.log_dir, 'codes', py[2:]))

formatted_print('Total Number of GPUs:', ngpus_per_node)
formatted_print('Total Number of Workers:', args.workers)
formatted_print('Batch Size:', args.batch_size)
formatted_print('Max image Size:', args.img_size_max)
formatted_print('Min image Size:', args.img_size_min)
formatted_print('Log DIR:', args.log_dir)
formatted_print('Result DIR:', args.res_dir)
formatted_print('GAN TYPE:', args.gantype)

if args.multiprocessing_distributed:
    args.world_size = ngpus_per_node * args.world_size
    mp.spawn(main_worker, nprocs=ngpus_per_node, args=(ngpus_per_node, args))
else:
    generator = main_worker(args.gpu, ngpus_per_node, args)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: You have chosen a specific GPU. This will completely disable data parallelism.
# Total Number of GPUs:                   1
# Total Number of Workers:                8
# Batch Size:                             2
# Max image Size:                         224
# Min image Size:                         28
# Log DIR:                                drive/dl_projects/Video_Genaeration/output/./logs/SinGan_2019-11-20_23-47-25
# Result DIR:                             drive/dl_projects/Video_Genaeration/output/./results/SinGan_2019-11-20_23-47-25
# GAN TYPE:                               zerogp
# Use GPU: 0 for training
# [28, 37, 49, 66, 88, 117, 157, 209]
# Stage: [0/7] Avg Loss: D[1.333] G[6.504] RMSE[1.000]:  20%|██        | 4/20 [00:02<00:11,  1.41it/s]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [0/7] Avg Loss: D[1.212] G[2.629] RMSE[1.000]: 100%|██████████| 20/20 [00:03<00:00, 10.14it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE
# Stage: [1/7] Avg Loss: D[1.073] G[5.347] RMSE[0.106]:  25%|██▌       | 5/20 [00:02<00:08,  1.79it/s]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [1/7] Avg Loss: D[0.987] G[2.880] RMSE[0.095]: 100%|██████████| 20/20 [00:03<00:00,  5.51it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE
# Stage: [2/7] Avg Loss: D[0.905] G[2.250] RMSE[0.093]:  30%|███       | 6/20 [00:02<00:08,  1.74it/s]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [2/7] Avg Loss: D[0.841] G[2.096] RMSE[0.087]: 100%|██████████| 20/20 [00:03<00:00,  8.67it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE
# Stage: [3/7] Avg Loss: D[0.791] G[2.131] RMSE[0.082]:  25%|██▌       | 5/20 [00:02<00:08,  1.71it/s]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [3/7] Avg Loss: D[0.713] G[2.092] RMSE[0.079]: 100%|██████████| 20/20 [00:04<00:00,  4.94it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE
# Stage: [4/7] Avg Loss: D[1.327] G[3.274] RMSE[0.089]:  25%|██▌       | 5/20 [00:02<00:09,  1.61it/s]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [4/7] Avg Loss: D[1.202] G[2.017] RMSE[0.081]: 100%|██████████| 20/20 [00:04<00:00,  8.46it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE
# Stage: [5/7] Avg Loss: D[1.102] G[1.889] RMSE[0.076]:  25%|██▌       | 5/20 [00:03<00:09,  1.53it/s]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [5/7] Avg Loss: D[0.945] G[1.739] RMSE[0.073]: 100%|██████████| 20/20 [00:05<00:00,  5.99it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE
# Stage: [6/7] Avg Loss: D[1.025] G[1.957] RMSE[0.082]:  20%|██        | 4/20 [00:03<00:14,  1.07it/s]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [6/7] Avg Loss: D[0.818] G[1.895] RMSE[0.075]: 100%|██████████| 20/20 [00:07<00:00,  3.87it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE
# Stage: [7/7] Avg Loss: D[1.138] G[1.850] RMSE[0.076]:  20%|██        | 4/20 [00:03<00:17,  1.09s/it]
# DISCRIMINATOR LEARNING RATE UPDATE TO : 5e-05
# GENERATOR LEARNING RATE UPDATE TO : 5e-05
# Stage: [7/7] Avg Loss: D[0.880] G[1.830] RMSE[0.079]: 100%|██████████| 20/20 [00:10<00:00,  2.37it/s]
# DISCRIMINATOR PROGRESSION DONE
# GENERATOR PROGRESSION DONE

# %%
data_loader = DataLoader(transformed_dataset, batch_size = args.batch_size,
                            sampler=torch.utils.data.SequentialSampler(transformed_dataset) ,  num_workers=args.workers)

# %%
def evaluate(stage, generator):
  train_it = iter(data_loader)

  x_in = next(train_it)

  x_in = x_in.cuda( non_blocking=True)
  x_org = x_in
  
  x_in = F.interpolate(x_in, (args.size_list[stage], args.size_list[stage]), mode='bilinear', align_corners=True)

  x_in_list = []
  print(len(args.size_list))
  for xidx in range(0, stage + 1):
      x_tmp = F.interpolate(x_org, (args.size_list[xidx], args.size_list[xidx]), mode='bilinear', align_corners=True)
      x_tmp = F.pad(x_tmp, [5, 5, 5, 5], value=0)
      x_in_list.append(x_tmp)
  generator.eval()
  out = generator(x_in_list)
  return out

# %%
for stage in range(args.stage, args.num_scale + 1):
  out = evaluate(stage,generator)
  networks =  generator
  generator.progress()
# Out:
# 8
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-e52deacedf66> in <module>()
#       1 for stage in range(args.stage, args.num_scale + 1):
# ----> 2   out = evaluate(stage,generator)
#       3   networks =  generator
#       4   generator.progress()
#       5
#
# <ipython-input-68-2437fe9c8847> in evaluate(stage, generator)
#      16       x_in_list.append(x_tmp)
#      17   generator.eval()
# ---> 18   out = generator(x_in_list)
#      19   return out
#      20
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-19-59cf12aebc2f> in forward(self, batch, img)
#      58             x_inter = F.pad(x_inter, [5, 5, 5, 5], value=0)
#      59             #print(self.current_scale)
# ---> 60             dim2 = dim1 = batch[i].shape[-1]
#      61             """
#      62             self.MHA= MultiHeadAttention(self.bs, self.h, self.d_model,  dim1,  dim2, self.dropout )
#
# IndexError: list index out of range

# %%
w = torch.empty(500,300)
a=  torch.empty(500,300)
a= nn.init.kaiming_uniform_(a, mode='fan_in')



nn.init.kaiming_uniform_(w, mode='fan_in')
(a*w).argmax()
# Out:
# tensor(12876)

# %%
w = torch.rand(32,256,20,20)
w.argmax()
# Out:
# tensor(2207442)

# %%
a=torch.chunk(w,8,dim=1)

# %%
c=torch.reshape(w,(8,32,32,20,20))

# %%
d=torch.stack(a,dim=0)

# %%
torch.equal(c,d)
# Out:
# False

# %%
torch.all(torch.lt(torch.abs(torch.add(c, -d)), 1e-1))
# Out:
# tensor(False)

# %%
sz=4
mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
print(mask)
mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
# Out:
# tensor([[ True, False, False, False],
#         [ True,  True, False, False],
#         [ True,  True,  True, False],
#         [ True,  True,  True,  True]])

# %%
mask
# Out:
# tensor([[0., -inf, -inf, -inf],
#         [0., 0., -inf, -inf],
#         [0., 0., 0., -inf],
#         [0., 0., 0., 0.]])

# %%
mask = (torch.triu(torch.ones(sz, sz)) == 1)

# %%
def mult_4d( batch, q_w, bs):
  layers = batch.shape[1]
  dim1 = batch.shape[2]
  dim2 = batch.shape[3]
  output = torch.bmm(batch.view(bs*layers,dim1,dim2), q_w.view(bs*layers,dim1,dim2))
  return output.view(bs,layers,dim1,dim2)

# %%
a=torch.tensor([[1,2],[3,4]])
b=torch.tensor([[1,2],[3,4]])
b@a
#torch.bmm(a.unsqueeze(0),b.unsqueeze(0))
# Out:
# tensor([[ 7, 10],
#         [15, 22]])

# %%
w = torch.rand(4,2,2,2)
a = torch.rand(4,2,2,2)
o=mult_4d(w,a.transpose(-2,-1),4)
#torch.bmm(w,a).shape
l=nn.Dropout()
l(o).shape
# Out:
# torch.Size([4, 2, 2, 2])

# %%
def generate_square_subsequent_mask(sz):
        r"""Generate a square mask for the sequence. The masked positions are filled with float('-inf').
            Unmasked positions are filled with float(0.0).
        """
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

mask= generate_square_subsequent_mask(4)
mask
# Out:
# tensor([[0., -inf, -inf, -inf],
#         [0., 0., -inf, -inf],
#         [0., 0., 0., -inf],
#         [0., 0., 0., 0.]])

# %%
mask.unsqueeze(0).unsqueeze(0)+a
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-08fed53c7ecf> in <module>()
# ----> 1 mask.unsqueeze(0).unsqueeze(0)+a
#
# RuntimeError: The size of tensor a (4) must match the size of tensor b (2) at non-singleton dimension 3

# %%
mask.unsqueeze(0).unsqueeze(0).shape
# Out:
# torch.Size([1, 1, 4, 4])

# %%
l=nn.Softmax2d()#.shape

# %%
c= l(mult_4d(w,a,w.shape[0]))

# %%
c.shape
# Out:
# torch.Size([4, 2, 2, 2])

# %%
l=nn.Softmax2d()#.shape

# %%
# For the current version: 
# !pip install --upgrade tensorflow
# Out:
# Collecting tensorflow
#   Downloading https://files.pythonhosted.org/packages/46/0f/7bd55361168bb32796b360ad15a25de6966c9c1beb58a8e30c01c8279862/tensorflow-2.0.0-cp36-cp36m-manylinux2010_x86_64.whl (86.3MB)
#      |████████████████████████████████| 86.3MB 124kB/s
# Collecting tensorboard<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/d3/9e/a48cd34dd7b672ffc227b566f7d16d63c62c58b542d54efa45848c395dd4/tensorboard-2.0.1-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 44.3MB/s
# Requirement already satisfied, skipping upgrade: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.8.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.1.8)
# Requirement already satisfied, skipping upgrade: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.33.6)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.8.1)
# Requirement already satisfied, skipping upgrade: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.17.4)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.11.2)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied, skipping upgrade: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (0.2.2)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.1.0)
# Collecting tensorflow-estimator<2.1.0,>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 42.0MB/s
# Requirement already satisfied, skipping upgrade: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.0.8)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.12.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (41.6.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.1)
# Collecting google-auth<2,>=1.6.3
#   Downloading https://files.pythonhosted.org/packages/7b/cb/786dc53d93494784935a62947643b48250b84a882474e714f9af5e1a1928/google_auth-1.7.1-py2.py3-none-any.whl (74kB)
#      |████████████████████████████████| 81kB 10.6MB/s
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.16.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow) (0.4.1)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow) (2.8.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (0.2.7)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.1)
# Requirement already satisfied, skipping upgrade: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (4.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow) (0.4.7)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (2.21.0)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (2.8)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (2019.9.11)
# Requirement already satisfied, skipping upgrade: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow) (1.24.3)
# ERROR: tensorboard 2.0.1 has requirement grpcio>=1.24.3, but you'll have grpcio 1.15.0 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement google-auth~=1.4.0, but you'll have google-auth 1.7.1 which is incompatible.
# Installing collected packages: google-auth, tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: google-auth 1.4.2
#     Uninstalling google-auth-1.4.2:
#       Successfully uninstalled google-auth-1.4.2
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# Successfully installed google-auth-1.7.1 tensorboard-2.0.1 tensorflow-2.0.0 tensorflow-estimator-2.0.1

# %%
import tensorflow as tf

# %%
transformed_dataset = CityscapeDataset(
                                           transforms=composed_transforms
                                           )

# %%
im_paths = transformed_dataset.im_path()

# %%
BUFFER_SIZE = 400
BATCH_SIZE = 32
IMG_WIDTH = 256
IMG_HEIGHT = 256
OUTPUT_CHANNELS = 3

# %%
def load(image_file):
  image = tf.io.read_file(image_file)
  image = tf.image.decode_jpeg(image)

  w = tf.shape(image)[1]

  w = w // 2
  
  input_image = image[:, w:, :]

  input_image = tf.cast(input_image, tf.float32)


  return input_image

# %%
def resize(input_image,  height, width):
  input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
 
  return input_image

def random_crop(input_image):
  stacked_image = tf.stack([input_image, input_image], axis=0)

  cropped_image = tf.image.random_crop(
      stacked_image, size=[2, IMG_HEIGHT, IMG_WIDTH, 3])

  return cropped_image[0]/127.5-1

# normalizing the images to [-1, 1]

def normalize(input_image):
  input_image = (input_image / 127.5) - 1


  return input_image

# %%
def random_jitter(input_image):
  # resizing to 286 x 286 x 3
  input_image = resize(input_image, 286, 286)

  # randomly cropping to 256 x 256 x 3
  input_image = random_crop(input_image)


  return input_image

# %%
def load_image_train(image_file):
  input_image = load(image_file)
  input_image = random_jitter(input_image)


  return input_image

# %%
#This genrates batches of specified sizes, functions uded in this can fe find in other files in repo,(augmentation,preprocess)
#It can be upadatesd for genrating  batches of test files to
def image_generator(input_ids, batch_size = 32,is_test =False):
  
  while True:

    if is_test:
      batch_input1 = []
      batch_input2 = []
      batch_input3 = []
      batch_paths =input_ids[is_test:batch_size+is_test]
      for input_id in batch_paths:
      
        input = load_image_train(input_id)
            
        batch_input1 += [input]
      is_test +=batch_size
      batch_paths =input_ids[is_test:batch_size+is_test]
      batch_input1 = tf.convert_to_tensor(batch_input1)
      for input_id in batch_paths:
      
        input = load_image_train(input_id)
            
        batch_input2 += [input]
      is_test +=batch_size
      batch_input2 = tf.convert_to_tensor(batch_input2)
      batch_paths =input_ids[is_test:batch_size+is_test]
      for input_id in batch_paths:
      
        input = load_image_train(input_id)
            
        batch_input3 += [input]
      batch_input3 = tf.convert_to_tensor(batch_input3)
      yield batch_input1, batch_input2, batch_input3

    batch_paths = np.random.choice(a= input_ids, size = batch_size)
    
    batch_input = []
   
    
    for input_id in batch_paths:
      #print(input_id)
      
      input = load_image_train(input_id)
            
      batch_input += [input]
      
    
    batch_x = tf.convert_to_tensor(
    batch_input,
    dtype=None,
    dtype_hint=None,
    name=None
)
    #print(2)
    
    
    yield (batch_x, batch_x)

# %%
gen = image_generator(im_paths, 4,is_test=1)

# %%
x,y = next(gen)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-26d6bcd7c8c6> in <module>()
# ----> 1 x,y = next(gen)
#
# ValueError: too many values to unpack (expected 2)

# %%
x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-9f2b259887ef> in <module>()
# ----> 1 x.shape
#
# NameError: name 'x' is not defined

# %%
def downsample(filters, size, apply_batchnorm=True):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

  if apply_batchnorm:
    result.add(tf.keras.layers.BatchNormalization())

  result.add(tf.keras.layers.LeakyReLU())

  return result

# %%
def upsample(filters, size, apply_dropout=False):
  initializer = tf.random_normal_initializer(0., 0.02)

  result = tf.keras.Sequential()
  
  result.add(
      
    tf.keras.layers.Conv2DTranspose(filters, size, strides=2,
                                    padding='same',
                                    kernel_initializer=initializer,
                                    use_bias=False))

  result.add(tf.keras.layers.BatchNormalization())

  if apply_dropout:
      result.add(tf.keras.layers.Dropout(0.5))

  result.add(tf.keras.layers.ReLU())

  return result

# %%
def Generator():
  down_stack = [
    downsample(64, 4, apply_batchnorm=False), # (bs, 128, 128, 64)
    downsample(128, 4), # (bs, 64, 64, 128)
    downsample(256, 4), # (bs, 32, 32, 256)
    downsample(512, 4), # (bs, 16, 16, 512)
    downsample(512, 4), # (bs, 8, 8, 512)
    downsample(512, 4), # (bs, 4, 4, 512)
    downsample(512, 4), # (bs, 2, 2, 512)
    downsample(512, 4), # (bs, 1, 1, 512)
  ]

  up_stack = [
    upsample(512, 4, apply_dropout=True), # (bs, 2, 2, 1024)
    upsample(512, 4, apply_dropout=True), # (bs, 4, 4, 1024)
    upsample(512, 4, apply_dropout=True), # (bs, 8, 8, 1024)
    upsample(512, 4), # (bs, 16, 16, 1024)
    upsample(256, 4), # (bs, 32, 32, 512)
    upsample(128, 4), # (bs, 64, 64, 256)
    upsample(64, 4), # (bs, 128, 128, 128)
  ]

  initializer = tf.random_normal_initializer(0., 0.02)
  
  last = tf.keras.layers.Conv2DTranspose(OUTPUT_CHANNELS, 4,
                                         strides=2,
                                         padding='same',
                                         kernel_initializer=initializer,
                                         activation='tanh') # (bs, 256, 256, 3)

  concat = tf.keras.layers.Concatenate()

  inputs = tf.keras.layers.Input(shape=[256,256,3])
  x = inputs

  # Downsampling through the model
  skips = []
  for down in down_stack:
    x = down(x)
    skips.append(x)

  skips = reversed(skips[:-1])

  # Upsampling and establishing the skip connections
  for up, skip in zip(up_stack, skips):
    x = up(x)
    x = concat([x, skip])

  x = last(x)

  return tf.keras.Model(inputs=inputs, outputs=x)

# %%
generator = Generator()

# %%
def Discriminator():
  initializer = tf.random_normal_initializer(0., 0.02)

  inp = tf.keras.layers.Input(shape=[256, 256, 3], name='input_image')
  tar = tf.keras.layers.Input(shape=[256, 256, 3], name='target_image')

  x = tf.keras.layers.concatenate([inp, tar]) # (bs, 256, 256, channels*2)

  down1 = downsample(64, 4, False)(x) # (bs, 128, 128, 64)
  down2 = downsample(128, 4)(down1) # (bs, 64, 64, 128)
  down3 = downsample(256, 4)(down2) # (bs, 32, 32, 256)

  zero_pad1 = tf.keras.layers.ZeroPadding2D()(down3) # (bs, 34, 34, 256)
  conv = tf.keras.layers.Conv2D(512, 4, strides=1,
                                kernel_initializer=initializer,
                                use_bias=False)(zero_pad1) # (bs, 31, 31, 512)

  batchnorm1 = tf.keras.layers.BatchNormalization()(conv)

  leaky_relu = tf.keras.layers.LeakyReLU()(batchnorm1)

  zero_pad2 = tf.keras.layers.ZeroPadding2D()(leaky_relu) # (bs, 33, 33, 512)

  last = tf.keras.layers.Conv2D(1, 4, strides=1,
                                kernel_initializer=initializer)(zero_pad2) # (bs, 30, 30, 1)

  return tf.keras.Model(inputs=[inp, tar], outputs=last)

# %%
discriminator = Discriminator()

# %%
LAMBDA = 100

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def discriminator_loss(disc_real_output, disc_generated_output):
  real_loss = loss_object(tf.ones_like(disc_real_output), disc_real_output)

  generated_loss = loss_object(tf.zeros_like(disc_generated_output), disc_generated_output)

  total_disc_loss = real_loss + generated_loss

  return total_disc_loss

# %%
def generator_loss(disc_generated_output, gen_output, target):
  gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

  # mean absolute error
  l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

  total_gen_loss = gan_loss + (LAMBDA * l1_loss)

  return total_gen_loss

# %%
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
checkpoint_dir = "drive/dl_projects/Video_Genaeration/pix2"
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer,
                                 generator=generator,
                                 discriminator=discriminator)

# %%
EPOCHS = 200

# %%
def generate_images(model, test_input):
  # the training=True is intentional here since
  # we want the batch statistics while running the model
  # on the test dataset. If we use training=False, we will get
  # the accumulated statistics learned from the training dataset
  # (which we don't want)
  prediction = model(test_input, training=True)
  plt.figure(figsize=(15,15))

  display_list = [test_input[0], prediction[0]]
  title = ['ground Image',  'Predicted Image']

  for i in range(2):
    plt.subplot(1, 2, i+1)
    plt.title(title[i])
    # getting the pixel values between [0, 1] to plot it.
    plt.imshow(display_list[i] * 0.5 + 0.5)
    plt.axis('off')
  plt.show()

# %%
def train_step(input_image, target):
  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    gen_output = generator(input_image, training=True)

    disc_real_output = discriminator([input_image, target], training=True)
    disc_generated_output = discriminator([input_image, gen_output], training=True)

    gen_loss = generator_loss(disc_generated_output, gen_output, target)
    disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

  generator_gradients = gen_tape.gradient(gen_loss,
                                          generator.trainable_variables)
  discriminator_gradients = disc_tape.gradient(disc_loss,
                                               discriminator.trainable_variables)

  generator_optimizer.apply_gradients(zip(generator_gradients,
                                          generator.trainable_variables))
  discriminator_optimizer.apply_gradients(zip(discriminator_gradients,
                                              discriminator.trainable_variables))

# %%
import time

# %%
def train(dataset, epochs):
  #print(1)
  for epoch in range(epochs):
    start = time.time()

    input_image , target = next(dataset)
    train_step(input_image, target)

    

    # saving (checkpoint) the model every 20 epochs
    if (epoch + 1) % 20 == 0:
      checkpoint.save(file_prefix = checkpoint_prefix)

    print ('Time taken for epoch {} is {} sec\n'.format(epoch + 1,
                                                        time.time()-start))

# %%
gen = image_generator(im_paths, 4)

# %%
x,y=(next(gen))
x.shape
# Out:
# TensorShape([4, 256, 256, 3])

# %%
EPOCHS = 100
train((gen), EPOCHS)
# Out:
# Time taken for epoch 1 is 14.991122722625732 sec
#
# Time taken for epoch 2 is 14.694751501083374 sec
#
# Time taken for epoch 3 is 14.723994493484497 sec
#
# Time taken for epoch 4 is 14.683447122573853 sec
#
# Time taken for epoch 5 is 14.75584602355957 sec
#
# Time taken for epoch 6 is 14.738471746444702 sec
#
# Time taken for epoch 7 is 14.781167030334473 sec
#
# Time taken for epoch 8 is 14.692874431610107 sec
#
# Time taken for epoch 9 is 14.760218381881714 sec
#
# Time taken for epoch 10 is 14.749069213867188 sec
#
# Time taken for epoch 11 is 14.626565217971802 sec
#
# Time taken for epoch 12 is 14.669948101043701 sec
#
# Time taken for epoch 13 is 14.712503910064697 sec
#
# Time taken for epoch 14 is 14.73608684539795 sec
#
# Time taken for epoch 15 is 14.63086485862732 sec
#
# Time taken for epoch 16 is 14.632611274719238 sec
#
# Time taken for epoch 17 is 14.791348934173584 sec
#
# Time taken for epoch 18 is 14.699128150939941 sec
#
# Time taken for epoch 19 is 14.642194032669067 sec
#
# Time taken for epoch 20 is 59.9327449798584 sec
#
# Time taken for epoch 21 is 14.43086290359497 sec
#
# Time taken for epoch 22 is 14.381453514099121 sec
#
# Time taken for epoch 23 is 14.33569049835205 sec
#
# Time taken for epoch 24 is 14.35711121559143 sec
#
# Time taken for epoch 25 is 14.416021823883057 sec
#
# Time taken for epoch 26 is 14.295656204223633 sec
#
# Time taken for epoch 27 is 14.592881202697754 sec
#
# Time taken for epoch 28 is 14.682474851608276 sec
#
# Time taken for epoch 29 is 14.375385284423828 sec
#
# Time taken for epoch 30 is 14.340277194976807 sec
#
# Time taken for epoch 31 is 14.306022644042969 sec
#
# Time taken for epoch 32 is 14.269595623016357 sec
#
# Time taken for epoch 33 is 14.382035493850708 sec
#
# Time taken for epoch 34 is 14.289440155029297 sec
#
# Time taken for epoch 35 is 14.343587160110474 sec
#
# Time taken for epoch 36 is 14.512308835983276 sec
#
# Time taken for epoch 37 is 14.390239477157593 sec
#
# Time taken for epoch 38 is 14.442610502243042 sec
#
# Time taken for epoch 39 is 14.38420557975769 sec
#
# Time taken for epoch 40 is 58.320364475250244 sec
#
# Time taken for epoch 41 is 14.452825784683228 sec
#
# Time taken for epoch 42 is 14.45037055015564 sec
#
# Time taken for epoch 43 is 14.485563516616821 sec
#
# Time taken for epoch 44 is 14.35458254814148 sec
#
# Time taken for epoch 45 is 14.447974681854248 sec
#
# Time taken for epoch 46 is 14.258443117141724 sec
#
# Time taken for epoch 47 is 14.329651832580566 sec
#
# Time taken for epoch 48 is 14.291353702545166 sec
#
# Time taken for epoch 49 is 14.193700790405273 sec
#
# Time taken for epoch 50 is 14.221541404724121 sec
#
# Time taken for epoch 51 is 14.322376012802124 sec
#
# Time taken for epoch 52 is 14.289353132247925 sec
#
# Time taken for epoch 53 is 14.272057294845581 sec
#
# Time taken for epoch 54 is 14.372947931289673 sec
#
# Time taken for epoch 55 is 14.327256202697754 sec
#
# Time taken for epoch 56 is 14.204650640487671 sec
#
# Time taken for epoch 57 is 14.297504901885986 sec
#
# Time taken for epoch 58 is 14.269780397415161 sec
#
# Time taken for epoch 59 is 14.250764608383179 sec
#
# Time taken for epoch 60 is 56.785704612731934 sec
#
# Time taken for epoch 61 is 14.422360181808472 sec
#
# Time taken for epoch 62 is 14.333606004714966 sec
#
# Time taken for epoch 63 is 14.788918018341064 sec
#
# Time taken for epoch 64 is 14.362422466278076 sec
#
# Time taken for epoch 65 is 14.388700723648071 sec
#
# Time taken for epoch 66 is 14.420192241668701 sec
#
# Time taken for epoch 67 is 14.393702507019043 sec
#
# Time taken for epoch 68 is 14.306219577789307 sec
#
# Time taken for epoch 69 is 14.331111669540405 sec
#
# Time taken for epoch 70 is 14.351057529449463 sec
#
# Time taken for epoch 71 is 14.356927871704102 sec
#
# Time taken for epoch 72 is 14.373358249664307 sec
#
# Time taken for epoch 73 is 14.561574697494507 sec
#
# Time taken for epoch 74 is 14.380658864974976 sec
#
# Time taken for epoch 75 is 14.43048357963562 sec
#
# Time taken for epoch 76 is 14.35025930404663 sec
#
# Time taken for epoch 77 is 14.39870548248291 sec
#
# Time taken for epoch 78 is 14.320833206176758 sec
#
# Time taken for epoch 79 is 14.392136335372925 sec
#
# Time taken for epoch 80 is 57.008976459503174 sec
#
# Time taken for epoch 81 is 14.470115184783936 sec
#
# Time taken for epoch 82 is 14.342580795288086 sec
#
# Time taken for epoch 83 is 14.358091592788696 sec
#
# Time taken for epoch 84 is 14.421027183532715 sec
#
# Time taken for epoch 85 is 14.366608142852783 sec
#
# Time taken for epoch 86 is 14.361937284469604 sec
#
# Time taken for epoch 87 is 14.360792875289917 sec
#
# Time taken for epoch 88 is 14.406756162643433 sec
#
# Time taken for epoch 89 is 14.380019187927246 sec
#
# Time taken for epoch 90 is 14.403473138809204 sec
#
# Time taken for epoch 91 is 14.458850622177124 sec
#
# Time taken for epoch 92 is 14.595468521118164 sec
#
# Time taken for epoch 93 is 14.410601377487183 sec
#
# Time taken for epoch 94 is 14.369938850402832 sec
#
# Time taken for epoch 95 is 14.39693021774292 sec
#
# Time taken for epoch 96 is 14.359314918518066 sec
#
# Time taken for epoch 97 is 14.49799132347107 sec
#
# Time taken for epoch 98 is 14.41746735572815 sec
#
# Time taken for epoch 99 is 14.446327686309814 sec
#
# Time taken for epoch 100 is 55.02031755447388 sec

# %%
def save_out(G):
  gen = image_generator(im_paths , 15, is_test = 5)
  a,b,c = next(gen)
  #print(b.shape)
  o1 = G(b/3+a*2)
  o2 = G(o1*2+c/3)
  print(o1.shape)
   # Converts to Image
  # Tensor

  batch = o1
  images = [tf.keras.preprocessing.image.array_to_img(im, data_format="channels_last") for im in batch]
  for i,image in enumerate(images):
    path ='drive/dl_projects/Video_Genaeration/result3/img_{}.jpg'.format(i)
    tf.keras.preprocessing.image.save_img(
    path,
    image

    )
  batch = o2
  images = [tf.keras.preprocessing.image.array_to_img(im, data_format="channels_last") for im in batch]
  for i,image in enumerate(images):
    path ='drive/dl_projects/Video_Genaeration/result3/imgb_{}.jpg'.format(i)
    tf.keras.preprocessing.image.save_img(
    path,
    image

    )

  batch = a
  images = [tf.keras.preprocessing.image.array_to_img(im, data_format="channels_last") for im in batch] # Convert images
  for i,image in enumerate(images):
    path ='drive/dl_projects/Video_Genaeration/result3/imgo_{}.jpg'.format(i)
    tf.keras.preprocessing.image.save_img(
    path,
    image
)
    # Do what you

# %%
save_out(generator)
# Out:
# (15, 256, 256, 3)

# %%
# importing libraries 
import os 
import cv2 
from PIL import Image 




# print(mean_height) 
# print(mean_width) 



# Video Generating function 
def generate_video(bs): 
  image_folder = '.' # make sure to use your folder 
  video_name = 'drive/dl_projects/Video_Genaeration/result3/mygeneratedvideo.avi'
   
  paths=[]

  ims=[]
  for i in range(bs+1):
    path ="drive/dl_projects/Video_Genaeration/result3/imgo_{}.jpg".format(i)
    im=cv2.imread(path)
    
    ims.append(im)
    paths.append(path)
  for i in range(bs+1):
    path ="drive/dl_projects/Video_Genaeration/result3/img_{}.jpg".format(i)
    im=cv2.imread(path)
    
    ims.append(im)
    paths.append(path)

  for i in range(bs+1):
    path ="drive/dl_projects/Video_Genaeration/result3/imgb_{}.jpg".format(i)
    im=cv2.imread(path)
    
    ims.append(im)
    paths.append(path)



  # Array images should only consider 
  # the image files ignoring others if any 
  
  print(path[0])
  frame = cv2.imread(paths[0]) 

  # setting the frame width, height width 
  # the width, height of first image 
  height, width, layers = ims[0].shape 

  video = cv2.VideoWriter(video_name, 0, 1, (width, height)) 

  print(len(ims))# Appending the images to the video one by one 
  for im in ims: 
    video.write(cv2.imread(path)) 

  # Deallocating memories taken for window creation 
  cv2.destroyAllWindows() 
  video.release() # releasing the video generated 


# Calling the generate_video function 
generate_video(15)
# Out:
# d
# 48

# %%
# restoring the latest checkpoint in checkpoint_dir
checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))
